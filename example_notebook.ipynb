# %%
import simple_finance as sf
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import simple_finance as sf
#       2 import pandas as pd
#
# ModuleNotFoundError: No module named 'simple_finance'
